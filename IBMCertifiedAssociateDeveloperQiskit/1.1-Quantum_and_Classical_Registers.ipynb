# %% [markdown]
# <a href="https://colab.research.google.com/github/mrromaniuc/quantum-computing/blob/main/IBMCertifiedAssociateDeveloperQiskit/1.1-Quantum_and_Classical_Registers.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from qiskit import QuantumRegister, ClassicalRegister, QuantumCircuit

# %%
qra = QuantumRegister(2, "a")
qrb = QuantumRegister(3, "b")

qc1 = QuantumCircuit(qra)
qc1.h(qra)
qc1.draw("mpl")

# %%
qc2 = QuantumCircuit(qra)
qc2.add_register(qrb)   #including more register after creating the circuit
qc2.h(qra)              #applying all operation to all qubits in the register
qc2.cx(qra[0], qra[1])  #Using inndexes
qc2.x(qrb)
qc2.draw("mpl")

# %%
cr = ClassicalRegister(2)

qc3 = QuantumCircuit(qra, cr)
qc3.h(qra)
qc3.measure(qra, cr)
qc3.draw("mpl")
